# %%
#Import libraries for analyis 

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import folium 
from folium import plugins
# %matplotlib inline

# %% [markdown]
# Data Overview

# %%
#load the ride and station datasets

trips_df = pd.read_csv('Resources/la_metro_gbfs_trips_2017.csv')


stations_df = pd.read_csv('Resources/metro-bike-share-stations-2019-10-1.csv')


trips_df.head(5)
# Out:
# C:\Users\alao8\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     trip_id  duration     start_time       end_time  start_station_id  \
# 0  17059131       480  1/1/2017 0:15  1/1/2017 0:23              3030
# 1  17059130       720  1/1/2017 0:24  1/1/2017 0:36              3028
# 2  17059129      1020  1/1/2017 0:28  1/1/2017 0:45              3027
# 3  17059128       300  1/1/2017 0:38  1/1/2017 0:43              3007
# 4  17059127       300  1/1/2017 0:38  1/1/2017 0:43              3007
#
#    start_lat   start_lon  end_station_id    end_lat     end_lon bike_id  \
# 0  34.051941 -118.243530            3029  34.048851 -118.246422    6220
# 1  34.058319 -118.246094            3028  34.058319 -118.246094    6351
# 2  34.049980 -118.247162            3018  34.043732 -118.260139    5836
# 3  34.050480 -118.254593            3031  34.044701 -118.252441    6142
# 4  34.050480 -118.254593            3031  34.044701 -118.252441    6135
#
#    plan_duration trip_route_category passholder_type
# 0           30.0             One Way    Monthly Pass
# 1            0.0          Round Trip         Walk-up
# 2            0.0             One Way         Walk-up
# 3           30.0             One Way    Monthly Pass
# 4           30.0             One Way    Monthly Pass

# %%
stations_df.head(5)
# Out:
#    Station_ID     Station_Name Go_live_date Region   Status
# 0        3000  Virtual Station     7/7/2016     NaN  Active
# 1        3005     7th & Flower     7/7/2016    DTLA  Active
# 2        3006      Olive & 8th     7/7/2016    DTLA  Active
# 3        3007      5th & Grand     7/7/2016    DTLA  Active
# 4        3008   Figueroa & 9th     7/7/2016    DTLA  Active

# %%
trips_df.shape
# Out:
# (229255, 14)

# %%
#Examine the data types 
trips_df.dtypes
# Out:
# trip_id                  int64
# duration                 int64
# start_time              object
# end_time                object
# start_station_id         int64
# start_lat              float64
# start_lon              float64
# end_station_id           int64
# end_lat                float64
# end_lon                float64
# bike_id                 object
# plan_duration          float64
# trip_route_category     object
# passholder_type         object
# dtype: object

# %%
# Examine any null values 
trips_df.isnull().sum()
# Out:
# trip_id                   0
# duration                  0
# start_time                0
# end_time                  0
# start_station_id          0
# start_lat               587
# start_lon               587
# end_station_id            0
# end_lat                3501
# end_lon                3501
# bike_id                   0
# plan_duration           384
# trip_route_category       0
# passholder_type           0
# dtype: int64

# %%
#Drop records with NaN values to keep data integrity
trips_clean = trips_df.dropna(how='any')

trips_clean.head()
# Out:
#     trip_id  duration     start_time       end_time  start_station_id  \
# 0  17059131       480  1/1/2017 0:15  1/1/2017 0:23              3030
# 1  17059130       720  1/1/2017 0:24  1/1/2017 0:36              3028
# 2  17059129      1020  1/1/2017 0:28  1/1/2017 0:45              3027
# 3  17059128       300  1/1/2017 0:38  1/1/2017 0:43              3007
# 4  17059127       300  1/1/2017 0:38  1/1/2017 0:43              3007
#
#    start_lat   start_lon  end_station_id    end_lat     end_lon bike_id  \
# 0  34.051941 -118.243530            3029  34.048851 -118.246422    6220
# 1  34.058319 -118.246094            3028  34.058319 -118.246094    6351
# 2  34.049980 -118.247162            3018  34.043732 -118.260139    5836
# 3  34.050480 -118.254593            3031  34.044701 -118.252441    6142
# 4  34.050480 -118.254593            3031  34.044701 -118.252441    6135
#
#    plan_duration trip_route_category passholder_type
# 0           30.0             One Way    Monthly Pass
# 1            0.0          Round Trip         Walk-up
# 2            0.0             One Way         Walk-up
# 3           30.0             One Way    Monthly Pass
# 4           30.0             One Way    Monthly Pass

# %%
#Confirm that records with NaN values are dropped
trips_clean.isnull().sum()
# Out:
# trip_id                0
# duration               0
# start_time             0
# end_time               0
# start_station_id       0
# start_lat              0
# start_lon              0
# end_station_id         0
# end_lat                0
# end_lon                0
# bike_id                0
# plan_duration          0
# trip_route_category    0
# passholder_type        0
# dtype: int64

# %%
stations_df.isnull().sum()

stations_clean = stations_df.dropna(how='any')

stations_clean.head()
# Out:
#    Station_ID    Station_Name Go_live_date Region   Status
# 1        3005    7th & Flower     7/7/2016    DTLA  Active
# 2        3006     Olive & 8th     7/7/2016    DTLA  Active
# 3        3007     5th & Grand     7/7/2016    DTLA  Active
# 4        3008  Figueroa & 9th     7/7/2016    DTLA  Active
# 5        3010    11th & Maple    7/10/2016    DTLA  Active

# %% [markdown]
# How many trips were taken in 2017?

# %%
trips_clean.trip_id.nunique()
# Out:
# 225034

# %%
#Lets confirm the table is unique at the table level.
trips_clean.shape[0]
# Out:
# 225034

# %% [markdown]
# How many unique stations?

# %%
stations_clean.Station_ID.nunique()
# Out:
# 244

# %%
stations_clean.Status.value_counts()
# Out:
# Active      181
# Inactive     63
# Name: Status, dtype: int64

# %% [markdown]
# What's the average duration of each trip?

# %%
#Each average trip duration is 216 min? On the website, https://bikeshare.metro.net/about/data/, it says duration is measured in minutes
trips_clean.duration.mean()
# Out:
# 216.43740945812633

# %%
#With the start and end times, the duration is actually measured in seconds which makes more sense now!
trips_clean[['duration', 'start_time','end_time']].head()
# Out:
#    duration     start_time       end_time
# 0       480  1/1/2017 0:15  1/1/2017 0:23
# 1       720  1/1/2017 0:24  1/1/2017 0:36
# 2      1020  1/1/2017 0:28  1/1/2017 0:45
# 3       300  1/1/2017 0:38  1/1/2017 0:43
# 4       300  1/1/2017 0:38  1/1/2017 0:43

# %%
#Create a new column for duration in minutes 
trips_clean['duration_min'] = trips_clean.duration/60

trips_clean.head()
# Out:
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     trip_id  duration     start_time       end_time  start_station_id  \
# 0  17059131       480  1/1/2017 0:15  1/1/2017 0:23              3030
# 1  17059130       720  1/1/2017 0:24  1/1/2017 0:36              3028
# 2  17059129      1020  1/1/2017 0:28  1/1/2017 0:45              3027
# 3  17059128       300  1/1/2017 0:38  1/1/2017 0:43              3007
# 4  17059127       300  1/1/2017 0:38  1/1/2017 0:43              3007
#
#    start_lat   start_lon  end_station_id    end_lat     end_lon bike_id  \
# 0  34.051941 -118.243530            3029  34.048851 -118.246422    6220
# 1  34.058319 -118.246094            3028  34.058319 -118.246094    6351
# 2  34.049980 -118.247162            3018  34.043732 -118.260139    5836
# 3  34.050480 -118.254593            3031  34.044701 -118.252441    6142
# 4  34.050480 -118.254593            3031  34.044701 -118.252441    6135
#
#    plan_duration trip_route_category passholder_type  duration_min
# 0           30.0             One Way    Monthly Pass           8.0
# 1            0.0          Round Trip         Walk-up          12.0
# 2            0.0             One Way         Walk-up          17.0
# 3           30.0             One Way    Monthly Pass           5.0
# 4           30.0             One Way    Monthly Pass           5.0

# %%
trips_clean.duration_min.mean()
# Out:
# 3.607290157636532

# %%
trips_clean.trip_route_category.value_counts()
# Out:
# One Way       195495
# Round Trip     29539
# Name: trip_route_category, dtype: int64

# %%
#Examine the distribution of membership types

membership_types = trips_clean.passholder_type.value_counts()

membership_types
# Out:
# Monthly Pass    142742
# Walk-up          65943
# Flex Pass        10937
# One Day Pass      5412
# Name: passholder_type, dtype: int64

# %%
#Plot a pie chart to represent their membership types
sns.set(rc={'figure.figsize':(10,10)})

labels = ['Monthly Pass', 'Walk-up', 'Flex Pass', 'One Day Pass']

plt.pie(membership_types, startangle=120, autopct='%1.1f%%')
plt.legend(labels, loc="upper right")
plt.title("Membership Types", fontsize=14)
plt.show()

# %% [markdown]
# 63.4% of their membership base are monthly subscribers. 29.3% are walk-ups meaning customers just purchase on the spot without any membership enrollment. Generally, a company profits when their most of their customers have a subscription-based membership.

# %%
trips_clean['start_time'].head()
# Out:
# 0    1/1/2017 0:15
# 1    1/1/2017 0:24
# 2    1/1/2017 0:28
# 3    1/1/2017 0:38
# 4    1/1/2017 0:38
# Name: start_time, dtype: object

# %%
#Convert to datetime format

trips_clean['start_time_dt'] = pd.to_datetime(trips_clean['start_time'])

trips_clean['end_time_dt'] = pd.to_datetime(trips_clean['end_time'])

trips_clean[['start_time_dt', 'end_time_dt']].head()
# Out:
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#         start_time_dt         end_time_dt
# 0 2017-01-01 00:15:00 2017-01-01 00:23:00
# 1 2017-01-01 00:24:00 2017-01-01 00:36:00
# 2 2017-01-01 00:28:00 2017-01-01 00:45:00
# 3 2017-01-01 00:38:00 2017-01-01 00:43:00
# 4 2017-01-01 00:38:00 2017-01-01 00:43:00

# %%
#Now we can extract year, month, and day once it datetime format 
trips_clean['year'] = trips_clean.start_time_dt.dt.year
trips_clean['month'] = trips_clean.start_time_dt.dt.month
trips_clean['day'] = trips_clean.start_time_dt.dt.day


# Days of the week where 0 is Monday and 6 is Sunday 
trips_clean['dayofweek'] = trips_clean.start_time_dt.dt.dayofweek
# Out:
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
monthly_trips = trips_clean.groupby(['year', 'month'])['trip_id'].count()
monthly_trips.plot()
plt.xlabel('Number of Trips')
plt.title('Monthly Trips Taken in 2017', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Monthly Trips Taken in 2017')

# %% [markdown]
# The highest number of trips were during October 2017. This high volumn of trips might be related to the moderate weather (72°), tourism, and possibly school commute. It's expected to have a low volume during the cold winter months of January and February and steadily increase as Spring arrives.

# %%
#Use categorical plot to view by passholder_type usage by month 


new_chart = sns.catplot(x='month', hue='passholder_type', data=trips_clean, col='passholder_type', kind= 'count')

# %%
#Let's see which day(s) have the lowest and highest volumns
day_trips = trips_clean.groupby(['dayofweek'])['trip_id'].count()
colors = ['blue', 'green', 'pink', 'orange', 'purple', 'red', 'grey']
labels = ('Mon', 'Tues', 'Wed',' Thur','Fri','Sat', 'Sun')
position = (0, 1, 2, 3, 4, 5, 6)
day_trips.plot(kind='bar', colors=colors, figsize=(8,6), rot=0)
plt.xticks(position, labels)
# Out:
# C:\Users\alao8\Anaconda3\lib\site-packages\pandas\plotting\_core.py:185: UserWarning: 'colors' is being deprecated. Please use 'color'instead of 'colors'
#   warnings.warn(("'colors' is being deprecated. Please use 'color'"
# ([<matplotlib.axis.XTick at 0x2d0ed50d6a0>,
#   <matplotlib.axis.XTick at 0x2d0ed50bef0>,
#   <matplotlib.axis.XTick at 0x2d0ed530ef0>,
#   <matplotlib.axis.XTick at 0x2d0ed53c208>,
#   <matplotlib.axis.XTick at 0x2d0ed53c710>,
#   <matplotlib.axis.XTick at 0x2d0ed53cbe0>,
#   <matplotlib.axis.XTick at 0x2d0ed53ce80>],
#  <a list of 7 Text xticklabel objects>)

# %% [markdown]
# It's not suprising to see that the highest trip volume is on Friday.

# %%
trips_clean.head()
# Out:
#     trip_id  duration     start_time       end_time  start_station_id  \
# 0  17059131       480  1/1/2017 0:15  1/1/2017 0:23              3030
# 1  17059130       720  1/1/2017 0:24  1/1/2017 0:36              3028
# 2  17059129      1020  1/1/2017 0:28  1/1/2017 0:45              3027
# 3  17059128       300  1/1/2017 0:38  1/1/2017 0:43              3007
# 4  17059127       300  1/1/2017 0:38  1/1/2017 0:43              3007
#
#    start_lat   start_lon  end_station_id    end_lat     end_lon  ...  \
# 0  34.051941 -118.243530            3029  34.048851 -118.246422  ...
# 1  34.058319 -118.246094            3028  34.058319 -118.246094  ...
# 2  34.049980 -118.247162            3018  34.043732 -118.260139  ...
# 3  34.050480 -118.254593            3031  34.044701 -118.252441  ...
# 4  34.050480 -118.254593            3031  34.044701 -118.252441  ...
#
#   plan_duration  trip_route_category passholder_type duration_min  \
# 0          30.0              One Way    Monthly Pass          8.0
# 1           0.0           Round Trip         Walk-up         12.0
# 2           0.0              One Way         Walk-up         17.0
# 3          30.0              One Way    Monthly Pass          5.0
# 4          30.0              One Way    Monthly Pass          5.0
#
#         start_time_dt         end_time_dt  year  month  day  dayofweek
# 0 2017-01-01 00:15:00 2017-01-01 00:23:00  2017      1    1          6
# 1 2017-01-01 00:24:00 2017-01-01 00:36:00  2017      1    1          6
# 2 2017-01-01 00:28:00 2017-01-01 00:45:00  2017      1    1          6
# 3 2017-01-01 00:38:00 2017-01-01 00:43:00  2017      1    1          6
# 4 2017-01-01 00:38:00 2017-01-01 00:43:00  2017      1    1          6
#
# [5 rows x 21 columns]

# %%
#Merge the trips and station dataframes to get starting station names 

trips_clean = trips_clean.rename(columns={'start_station_id': 'Station_ID'})

trips_clean = trips_clean.merge(stations_clean[['Station_ID', 'Station_Name']], on='Station_ID', how='left')

trips_clean = trips_clean.rename(columns ={'Station_ID' : 'Start_Station_ID',
                                          'Station_Name' : 'Station_Name_Start'})

trips_clean.head()
# Out:
#     trip_id  duration     start_time       end_time  Start_Station_ID  \
# 0  17059131       480  1/1/2017 0:15  1/1/2017 0:23              3030
# 1  17059130       720  1/1/2017 0:24  1/1/2017 0:36              3028
# 2  17059129      1020  1/1/2017 0:28  1/1/2017 0:45              3027
# 3  17059128       300  1/1/2017 0:38  1/1/2017 0:43              3007
# 4  17059127       300  1/1/2017 0:38  1/1/2017 0:43              3007
#
#    start_lat   start_lon  end_station_id    end_lat     end_lon  ...  \
# 0  34.051941 -118.243530            3029  34.048851 -118.246422  ...
# 1  34.058319 -118.246094            3028  34.058319 -118.246094  ...
# 2  34.049980 -118.247162            3018  34.043732 -118.260139  ...
# 3  34.050480 -118.254593            3031  34.044701 -118.252441  ...
# 4  34.050480 -118.254593            3031  34.044701 -118.252441  ...
#
#   trip_route_category  passholder_type duration_min       start_time_dt  \
# 0             One Way     Monthly Pass          8.0 2017-01-01 00:15:00
# 1          Round Trip          Walk-up         12.0 2017-01-01 00:24:00
# 2             One Way          Walk-up         17.0 2017-01-01 00:28:00
# 3             One Way     Monthly Pass          5.0 2017-01-01 00:38:00
# 4             One Way     Monthly Pass          5.0 2017-01-01 00:38:00
#
#           end_time_dt  year month  day  dayofweek  Station_Name_Start
# 0 2017-01-01 00:23:00  2017     1    1          6          Main & 1st
# 1 2017-01-01 00:36:00  2017     1    1          6      Grand & Temple
# 2 2017-01-01 00:45:00  2017     1    1          6        Spring & 3rd
# 3 2017-01-01 00:43:00  2017     1    1          6         5th & Grand
# 4 2017-01-01 00:43:00  2017     1    1          6         5th & Grand
#
# [5 rows x 22 columns]

# %%
# #Merge the trips and station dataframes to get ending station names 
trips_clean = trips_clean.rename(columns={'end_station_id':'End_Station_ID'})

stations_clean = stations_clean.rename(columns={'Station_ID' : 'End_Station_ID'})

trips_clean = trips_clean.merge(stations_clean[['End_Station_ID', 'Station_Name']], on='End_Station_ID', how='left')

trips_clean = trips_clean.rename(columns={'Station_Name': 'Station_Name_End'})

trips_clean.head(20)
# Out:
#      trip_id  duration     start_time       end_time  Start_Station_ID  \
# 0   17059131       480  1/1/2017 0:15  1/1/2017 0:23              3030
# 1   17059130       720  1/1/2017 0:24  1/1/2017 0:36              3028
# 2   17059129      1020  1/1/2017 0:28  1/1/2017 0:45              3027
# 3   17059128       300  1/1/2017 0:38  1/1/2017 0:43              3007
# 4   17059127       300  1/1/2017 0:38  1/1/2017 0:43              3007
# 5   17059126      1200  1/1/2017 0:39  1/1/2017 0:59              3066
# 6   17059125       720  1/1/2017 0:43  1/1/2017 0:55              3029
# 7   17061379      2880  1/1/2017 0:56  1/1/2017 1:44              3063
# 8   17061378      2820  1/1/2017 0:57  1/1/2017 1:44              3063
# 9   17063646      1500  1/1/2017 1:54  1/1/2017 2:19              3078
# 10  17063645      1440  1/1/2017 1:55  1/1/2017 2:19              3078
# 11  17063644      1200  1/1/2017 1:56  1/1/2017 2:16              3082
# 12  17063643      1320  1/1/2017 1:58  1/1/2017 2:20              3078
# 13  17063642      1200  1/1/2017 1:59  1/1/2017 2:19              3078
# 14  17063640       960  1/1/2017 2:00  1/1/2017 2:16              3082
# 15  17063641      1140  1/1/2017 2:00  1/1/2017 2:19              3078
# 16  17063639      1140  1/1/2017 2:01  1/1/2017 2:20              3078
# 17  17063638       300  1/1/2017 2:12  1/1/2017 2:17              3052
# 18  17063637       480  1/1/2017 2:19  1/1/2017 2:27              3008
# 19  17063636       480  1/1/2017 2:20  1/1/2017 2:28              3008
#
#     start_lat   start_lon   End_Station_ID    end_lat     end_lon  ...  \
# 0   34.051941 -118.243530             3029  34.048851 -118.246422  ...
# 1   34.058319 -118.246094             3028  34.058319 -118.246094  ...
# 2   34.049980 -118.247162             3018  34.043732 -118.260139  ...
# 3   34.050480 -118.254593             3031  34.044701 -118.252441  ...
# 4   34.050480 -118.254593             3031  34.044701 -118.252441  ...
# 5   34.063389 -118.236160             3055  34.044159 -118.251579  ...
# 6   34.048851 -118.246422             3079  34.050140 -118.233238  ...
# 7   34.049198 -118.252831             3063  34.049198 -118.252831  ...
# 8   34.049198 -118.252831             3063  34.049198 -118.252831  ...
# 9   34.064281 -118.238937             3023  34.050911 -118.240967  ...
# 10  34.064281 -118.238937             3023  34.050911 -118.240967  ...
# 11  34.046520 -118.237411             3008  34.046612 -118.262733  ...
# 12  34.064281 -118.238937             3023  34.050911 -118.240967  ...
# 13  34.064281 -118.238937             3023  34.050911 -118.240967  ...
# 14  34.046520 -118.237411             3008  34.046612 -118.262733  ...
# 15  34.064281 -118.238937             3023  34.050911 -118.240967  ...
# 16  34.064281 -118.238937             3023  34.050911 -118.240967  ...
# 17  34.051102 -118.264557             3031  34.044701 -118.252441  ...
# 18  34.046612 -118.262733             3049  34.056969 -118.253593  ...
# 19  34.046612 -118.262733             3049  34.056969 -118.253593  ...
#
#    passholder_type  duration_min       start_time_dt         end_time_dt  \
# 0     Monthly Pass           8.0 2017-01-01 00:15:00 2017-01-01 00:23:00
# 1          Walk-up          12.0 2017-01-01 00:24:00 2017-01-01 00:36:00
# 2          Walk-up          17.0 2017-01-01 00:28:00 2017-01-01 00:45:00
# 3     Monthly Pass           5.0 2017-01-01 00:38:00 2017-01-01 00:43:00
# 4     Monthly Pass           5.0 2017-01-01 00:38:00 2017-01-01 00:43:00
# 5          Walk-up          20.0 2017-01-01 00:39:00 2017-01-01 00:59:00
# 6          Walk-up          12.0 2017-01-01 00:43:00 2017-01-01 00:55:00
# 7          Walk-up          48.0 2017-01-01 00:56:00 2017-01-01 01:44:00
# 8          Walk-up          47.0 2017-01-01 00:57:00 2017-01-01 01:44:00
# 9          Walk-up          25.0 2017-01-01 01:54:00 2017-01-01 02:19:00
# 10         Walk-up          24.0 2017-01-01 01:55:00 2017-01-01 02:19:00
# 11    Monthly Pass          20.0 2017-01-01 01:56:00 2017-01-01 02:16:00
# 12         Walk-up          22.0 2017-01-01 01:58:00 2017-01-01 02:20:00
# 13         Walk-up          20.0 2017-01-01 01:59:00 2017-01-01 02:19:00
# 14         Walk-up          16.0 2017-01-01 02:00:00 2017-01-01 02:16:00
# 15         Walk-up          19.0 2017-01-01 02:00:00 2017-01-01 02:19:00
# 16         Walk-up          19.0 2017-01-01 02:01:00 2017-01-01 02:20:00
# 17    Monthly Pass           5.0 2017-01-01 02:12:00 2017-01-01 02:17:00
# 18    Monthly Pass           8.0 2017-01-01 02:19:00 2017-01-01 02:27:00
# 19         Walk-up           8.0 2017-01-01 02:20:00 2017-01-01 02:28:00
#
#     year month day  dayofweek  Station_Name_Start       End_Station_Name
# 0   2017     1   1          6          Main & 1st             Main & 4th
# 1   2017     1   1          6      Grand & Temple         Grand & Temple
# 2   2017     1   1          6        Spring & 3rd        Grand & Olympic
# 3   2017     1   1          6         5th & Grand           7th & Spring
# 4   2017     1   1          6         5th & Grand           7th & Spring
# 5   2017     1   1          6    Spring & College             7th & Main
# 6   2017     1   1          6          Main & 4th        Temple & Vignes
# 7   2017     1   1          6         Olive & 5th            Olive & 5th
# 8   2017     1   1          6         Olive & 5th            Olive & 5th
# 9   2017     1   1          6      Hill & College  1st & Judge John Aiso
# 10  2017     1   1          6      Hill & College  1st & Judge John Aiso
# 11  2017     1   1          6     Traction & Rose         Figueroa & 9th
# 12  2017     1   1          6      Hill & College  1st & Judge John Aiso
# 13  2017     1   1          6      Hill & College  1st & Judge John Aiso
# 14  2017     1   1          6     Traction & Rose         Figueroa & 9th
# 15  2017     1   1          6      Hill & College  1st & Judge John Aiso
# 16  2017     1   1          6      Hill & College  1st & Judge John Aiso
# 17  2017     1   1          6         7th & Bixel           7th & Spring
# 18  2017     1   1          6      Figueroa & 9th         2nd & Figueroa
# 19  2017     1   1          6      Figueroa & 9th         2nd & Figueroa
#
# [20 rows x 23 columns]

# %%
#Lets see which is the most popular start stations 

pop_start_station = trips_clean.groupby(['Station_Name_Start'])['trip_id'].count().sort_values(ascending=False)


pop_start_stations = pop_start_station[:50]
pop_start_stations
# Out:
# Station_Name_Start
# 7th & Flower                               8891
# Traction & Rose                            7069
# Grand & 7th                                6946
# Union Station West Portal                  6542
# 7th & Spring                               6388
# Broadway & 3rd                             6306
# Main & 1st                                 6209
# Grand & 3rd                                5899
# 1st & Central                              5394
# Main & 6th                                 4970
# 3rd & Santa Fe                             4893
# Figueroa & 8th                             4857
# 2nd & Figueroa                             4536
# Main & 5th                                 4476
# 5th & Grand                                4281
# Ocean Front Walk & Navy                    4250
# 5th & Hewitt                               4227
# 7th & Main                                 4047
# Olive & 8th                                3825
# Hope & 11th                                3812
# Olive & 5th                                3655
# Hope & Olympic                             3600
# Hope & 6th                                 3325
# Broadway & 9th                             3293
# Spring & 3rd                               3277
# 3rd & San Pedro                            3241
# Figueroa & 9th                             3221
# Ocean Front Walk & North Venice            3147
# 7th & Bixel                                2992
# Pico & Flower                              2985
# Spring & College                           2779
# 9th & Los Angeles                          2614
# Main & 4th                                 2596
# 7th & Broadway                             2595
# 12th & Hill                                2275
# Figueroa & Cesar Chavez                    2248
# Grand & Olympic                            2205
# Figueroa & Pico                            2132
# 1st & Judge John Aiso                      2132
# Downtown Santa Monica Expo Line Station    2072
# Industrial St & Mateo St                   1948
# 2nd & Hill                                 1938
# Grand & Temple                             1694
# Los Angeles & Temple                       1662
# Factory Place & Alameda                    1565
# Wilshire & Witmer                          1461
# Memorial Park Station                      1429
# Hill & College                             1418
# Imperial & 7th                             1383
# Willow St & Mateo St                       1341
# Name: trip_id, dtype: int64

# %%
pop_start_stations.plot.barh()

# %%
pop_end_station = trips_clean.groupby(['End_Station_Name'])['trip_id'].count().sort_values(ascending=False)

pop_end_stations = pop_end_station[:50]
pop_end_stations
# Out:
# End_Station_Name
# 7th & Flower                               10409
# Traction & Rose                             8235
# Union Station West Portal                   7344
# 7th & Spring                                7309
# 1st & Central                               6871
# Grand & 7th                                 6862
# Broadway & 3rd                              6769
# Figueroa & 8th                              5404
# 3rd & Santa Fe                              5290
# Main & 1st                                  5209
# Olive & 5th                                 5063
# 5th & Hewitt                                4449
# Main & 6th                                  4437
# Main & 5th                                  4406
# Hope & 11th                                 4099
# Hope & 6th                                  4065
# Downtown Santa Monica Expo Line Station     3981
# Olive & 8th                                 3920
# Broadway & 9th                              3700
# Ocean Front Walk & Navy                     3567
# 2nd & Figueroa                              3467
# Figueroa & 9th                              3386
# Hope & Olympic                              3323
# 3rd & San Pedro                             3310
# 7th & Main                                  3273
# 5th & Grand                                 3248
# Pico & Flower                               3013
# 7th & Broadway                              2762
# Ocean Front Walk & North Venice             2712
# 1st & Judge John Aiso                       2706
# 9th & Los Angeles                           2678
# Spring & College                            2665
# 12th & Hill                                 2665
# Figueroa & Pico                             2620
# Grand & Olympic                             2504
# Spring & 3rd                                2459
# Industrial St & Mateo St                    2022
# Main & 4th                                  1990
# 7th & Bixel                                 1908
# Willow St & Mateo St                        1783
# 2nd & Hill                                  1759
# Factory Place & Alameda                     1736
# Imperial & 7th                              1701
# Figueroa & Cesar Chavez                     1650
# Memorial Park Station                       1494
# Los Angeles & Temple                        1479
# Grand & 14th                                1436
# Grand & 3rd                                 1403
# Hill & College                              1326
# Del Mar Station                             1315
# Name: trip_id, dtype: int64

# %%
pop_end_stations.plot.barh()

# %%
trips_clean.head()
# Out:
#     trip_id  duration     start_time       end_time  Start_Station_ID  \
# 0  17059131       480  1/1/2017 0:15  1/1/2017 0:23              3030
# 1  17059130       720  1/1/2017 0:24  1/1/2017 0:36              3028
# 2  17059129      1020  1/1/2017 0:28  1/1/2017 0:45              3027
# 3  17059128       300  1/1/2017 0:38  1/1/2017 0:43              3007
# 4  17059127       300  1/1/2017 0:38  1/1/2017 0:43              3007
#
#    start_lat   start_lon   End_Station_ID    end_lat     end_lon  ...  \
# 0  34.051941 -118.243530             3029  34.048851 -118.246422  ...
# 1  34.058319 -118.246094             3028  34.058319 -118.246094  ...
# 2  34.049980 -118.247162             3018  34.043732 -118.260139  ...
# 3  34.050480 -118.254593             3031  34.044701 -118.252441  ...
# 4  34.050480 -118.254593             3031  34.044701 -118.252441  ...
#
#   passholder_type  duration_min       start_time_dt         end_time_dt  year  \
# 0    Monthly Pass           8.0 2017-01-01 00:15:00 2017-01-01 00:23:00  2017
# 1         Walk-up          12.0 2017-01-01 00:24:00 2017-01-01 00:36:00  2017
# 2         Walk-up          17.0 2017-01-01 00:28:00 2017-01-01 00:45:00  2017
# 3    Monthly Pass           5.0 2017-01-01 00:38:00 2017-01-01 00:43:00  2017
# 4    Monthly Pass           5.0 2017-01-01 00:38:00 2017-01-01 00:43:00  2017
#
#   month day  dayofweek  Station_Name_Start  End_Station_Name
# 0     1   1          6          Main & 1st        Main & 4th
# 1     1   1          6      Grand & Temple    Grand & Temple
# 2     1   1          6        Spring & 3rd   Grand & Olympic
# 3     1   1          6         5th & Grand      7th & Spring
# 4     1   1          6         5th & Grand      7th & Spring
#
# [5 rows x 23 columns]

# %%
#Use folium to get a map. We will create a function with the 'average' start lat and start lon coordinates 

def get_base_map(trips_clean):
    return folium.Map(location=[trips_clean['start_lat'].mean(), trips_clean['start_lon'].mean()],
                     zoom_start=12)


#Get base map 

base_map = get_base_map(trips_clean)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Let visualize the start stations with markers 

def station_markers(initial_map, trips_clean):
    station_df = trips_clean.drop_duplicates(subset=['Start_Station_ID'])
    out_map = initial_map 
    for lat, lon, name in zip(station_df['start_lat'], station_df['start_lon'], station_df['Station_Name_Start']):
        out_map.add_child(folium.Marker(location =[lat, lon], popup=(folium.Popup(name))))
    return out_map

markers = station_markers(base_map, trips_clean)

markers
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\Anaconda3\lib\site-packages\folium\folium.py in _repr_html_(self, **kwargs)
#     291             self._parent = None
#     292         else:
# --> 293             out = self._parent._repr_html_(**kwargs)
#     294         return out
#     295
#
# ~\Anaconda3\lib\site-packages\branca\element.py in _repr_html_(self, **kwargs)
#     326
#     327         """
# --> 328         html = self.render(**kwargs)
#     329         html = "data:text/html;charset=utf-8;base64," + base64.b64encode(html.encode('utf8')).decode('utf8')  # noqa
#     330
#
# ~\Anaconda3\lib\site-packages\branca\element.py in render(self, **kwargs)
#     319         """Renders the HTML representation of the element."""
#     320         for name, child in self._children.items():
# --> 321             child.render(**kwargs)
#     322         return self._template.render(this=self, kwargs=kwargs)
#     323
#
# ~\Anaconda3\lib\site-packages\folium\folium.py in render(self, **kwargs)
#     368             '</style>'), name='map_style')
#     369
# --> 370         super(Map, self).render(**kwargs)
#     371
#     372     def fit_bounds(self, bounds, padding_top_left=None,
#
# ~\Anaconda3\lib\site-packages\branca\element.py in render(self, **kwargs)
#     631
#     632         for name, element in self._children.items():
# --> 633             element.render(**kwargs)
#
# ~\Anaconda3\lib\site-packages\folium\folium.py in render(self, **kwargs)
#     368             '</style>'), name='map_style')
#     369
# --> 370         super(Map, self).render(**kwargs)
#     371
#     372     def fit_bounds(self, bounds, padding_top_left=None,
#
# ~\Anaconda3\lib\site-packages\branca\element.py in render(self, **kwargs)
#     627         script = self._template.module.__dict__.get('script', None)
#     628         if script is not None:
# --> 629             figure.script.add_child(Element(script(self, kwargs)),
#     630                                     name=self.get_name())
#     631
#
# ~\Anaconda3\lib\site-packages\jinja2\runtime.py in __call__(self, *args, **kwargs)
#     573                             (self.name, len(self.arguments)))
#     574
# --> 575         return self._invoke(arguments, autoescape)
#     576
#     577     def _invoke(self, arguments, autoescape):
#
# ~\Anaconda3\lib\site-packages\jinja2\asyncsupport.py in _invoke(self, arguments, autoescape)
#     108     def _invoke(self, arguments, autoescape):
#     109         if not self._environment.is_async:
# --> 110             return original_invoke(self, arguments, autoescape)
#     111         return async_invoke(self, arguments, autoescape)
#     112     return update_wrapper(_invoke, original_invoke)
#
# ~\Anaconda3\lib\site-packages\jinja2\runtime.py in _invoke(self, arguments, autoescape)
#     577     def _invoke(self, arguments, autoescape):
#     578         """This method is being swapped out by the async implementation."""
# --> 579         rv = self._func(*arguments)
#     580         if autoescape:
#     581             rv = Markup(rv)
#
# <template> in macro(l_1_this, l_1_kwargs)
#
# ~\Anaconda3\lib\site-packages\jinja2\filters.py in do_tojson(eval_ctx, value, indent)
#    1076         options = dict(options)
#    1077         options['indent'] = indent
# -> 1078     return htmlsafe_json_dumps(value, dumper=dumper, **options)
#    1079
#    1080
#
# ~\Anaconda3\lib\site-packages\jinja2\utils.py in htmlsafe_json_dumps(obj, dumper, **kwargs)
#     563     if dumper is None:
#     564         dumper = json.dumps
# --> 565     rv = dumper(obj, **kwargs) \
#     566         .replace(u'<', u'\\u003c') \
#     567         .replace(u'>', u'\\u003e') \
#
# ~\Anaconda3\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# ~\Anaconda3\lib\json\encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# ~\Anaconda3\lib\json\encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# ~\Anaconda3\lib\json\encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type Popup is not JSON serializable
